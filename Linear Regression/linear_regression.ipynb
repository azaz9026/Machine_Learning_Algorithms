# %% [markdown]
# # Linear Regression
#
#
# ***Linear regression is a type of supervised machine learningalgorithm that computes the linear relationship between a dependent variable and one or more independent features***

# %% [markdown]
# ***Linear regression with Single variable***
#
# ***Linear regression with Multiple variable***

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.DataFrame({'Age' : [25,30,35,40,45] , 'Permium' : [18000,32000,40000,47000,55000]})

# %%
df
# Out:
#    Age  Permium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
sns.lmplot(x='Age', y='Permium', data=df)

# %%
reg = linear_model.LinearRegression()

reg.fit(df[['Age']],df['Permium'])
# Out:
# LinearRegression()

# %%
reg.predict([[50]])
# Out:
# c:\Users\mdaza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65100.])

# %% [markdown]
# # Y = M * X + C

# %% [markdown]
# ***prediction for Premium whose age is 50***

# %%
reg.coef_
# Out:
# array([1780.])

# %%
reg.intercept_
# Out:
# -23899.999999999985

# %%
# y = m*x+c

y = 1780 * 50 + (-23899)

print(y)
# Out:
# 65101

# %%
reg.predict([[21]])
# Out:
# c:\Users\mdaza\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13480.])

# %% [markdown]
# # Y = M * X + C

# %% [markdown]
# ***prediction for Premium whose age is 21***

# %%
reg.coef_
# Out:
# array([1780.])

# %%
reg.intercept_
# Out:
# -23899.999999999985

# %%
# y = m*x+c

y = 1780 * 21 + (-23899)

print(y)
# Out:
# 13481
